# %% [markdown]
# ## Load the web page content

# %%
import requests

# URL of the website
url = 'https://www.bbc.com/news'

# Fetch the webpage content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    print("Page loaded successfully.")
    print(response.content[:1000])  # Print the first 1000 characters to verify we're loading the page
else:
    print(f"Failed to retrieve content. Status code: {response.status_code}")
# Out:
# Page loaded successfully.
# b'<!DOCTYPE html><html lang="en-GB"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><title>Home - BBC News</title><meta property="og:title" content="Home - BBC News"/><meta name="twitter:title" content="Home - BBC News"/><meta name="description" content="Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news."/><meta property="og:description" content="Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news."/><meta name="twitter:description" content="Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news '

# %% [markdown]
# ## Find tags and their class attributes

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website
url = 'https://www.bbc.com/news'

# Fetch the webpage content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find and print all h1, h2, h3 tags with their class attributes
    for tag in ['h1', 'h2', 'h3', 'h4']:
        print(f"\n--- {tag.upper()} Tags ---")
        for element in soup.find_all(tag):
            print(f"Tag: {tag}, Text: {element.get_text()}, Class: {element.get('class')}")
else:
    print(f"Failed to retrieve content. Status code: {response.status_code}")
# Out:
# --- H1 Tags ---
# Tag: h1, Text: NewsNews, Class: None
#
# --- H2 Tags ---
# Tag: h2, Text: Sri Lanka election goes to historic second count, Class: ['sc-4fedabc7-3', 'dsoipF']
# Tag: h2, Text: Hezbollah rocket attacks damage homes in Israel, while IDF launches more Lebanon strikes, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Israel orders 45-day closure of Al Jazeera West Bank office, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: MrBeast is called the internet's nicest man - now he faces 54-page lawsuit, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: CPS twice did not prosecute Fayed over sex abuse claims, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Hezbollah rocket attacks damage homes in Israel, while IDF launches more Lebanon strikes, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Four dead and dozens hurt in Alabama mass shooting, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Macron unveils new right-wing French government, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: At least 51 dead in Iran coal mine explosion, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Israel orders 45-day closure of Al Jazeera West Bank office, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: One dead and several missing after 'unprecedented' rains in Japan, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Trump rejects second TV debate as 'too late', Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: How Punjabi megastar Diljit Dosanjh is inspiring the next gen, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Dissident in prisoner swap vows to return to Russia, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Joshua future in doubt after mauling by dominant Dubois, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: More to explore, Class: ['sc-6f766713-4', 'elqzuS']
# Tag: h2, Text: Amazon says workers must be in the office. The UK government disagrees. Who is right?, Class: ['sc-4fedabc7-3', 'dsoipF']
# Tag: h2, Text: China spent millions on this new trade route - then a war got in the way, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Mysterious hate letters turn quiet village to 'poison', Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Why Katy Perry's comeback has gone so wrong, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Hezbollah device explosions: The unanswered questions, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: China spent millions on this new trade route - then a war got in the way, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: The journey that helped save Nigeria's art for the nation, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Bella Mackie: Americans romanticise posh Brits, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: 'I travelled from Edinburgh to Antarctica to create music'   , Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Mysterious hate letters turn quiet village to 'poison', Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Most watched, Class: ['sc-6f766713-4', 'elqzuS']
# Tag: h2, Text: Watch: Huge explosion at Russia arms depot, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Watch: Russia dissident freed in prisoner swap vows to return, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Watch: Hundreds of paratroopers leap to mark daring WW2 offensive, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Woman flees after running man over with his own Porsche, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Watch: Burning Canadian bridge collapses into river, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Also in news, Class: ['sc-6f766713-4', 'elqzuS']
# Tag: h2, Text: Your pictures on the theme of 'railways' , Class: ['sc-4fedabc7-3', 'dsoipF']
# Tag: h2, Text: US soldier who fled to North Korea sentenced for desertion , Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Secret Service admits 'complacency' before Trump rally shooting, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Ukraine bans Telegram use on state-issued devices, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: South Carolina executes first inmate in 13 years, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: US soldier who fled to North Korea sentenced for desertion , Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: California fire agency worker faces arson charges, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Israel strike kills 22 in Gaza school, says Hamas-run health ministry, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Secret Service admits 'complacency' before Trump rally shooting, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Most read, Class: ['sc-6f766713-4', 'elqzuS']
# Tag: h2, Text: Four dead and dozens hurt in Alabama mass shooting, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Sri Lanka election goes to historic second count, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: MrBeast is called the internet's nicest man - now he faces 54-page lawsuit, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: How Punjabi megastar Diljit Dosanjh is inspiring the next gen, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: At least 51 dead in Iran coal mine explosion, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Israel orders 45-day closure of Al Jazeera West Bank office, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Macron unveils new right-wing French government, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Israel launches new strikes as Hezbollah fires dozens of rockets, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: CPS twice did not prosecute Fayed over sex abuse claims, Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Trump rejects second TV debate as 'too late', Class: ['sc-4fedabc7-3', 'gJvjEE']
# Tag: h2, Text: Sport, Class: ['sc-6f766713-4', 'elqzuS']
# Tag: h2, Text: 'Young pretender Dubois legitimises world title reign', Class: ['sc-4fedabc7-3', 'dsoipF']
# Tag: h2, Text: Verstappen restricts answers after 'ridiculous' swearing punishment, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: 'Disaster' to 'winning machine' - is Rodri the best in the world?, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Argentina beat SA to keep Rugby Championship alive, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Kane breaks Bundesliga record as Bayern cruise at Bremen, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Verstappen restricts answers after 'ridiculous' swearing punishment, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: People expect Man City to be wiped 'from face of Earth', Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Joshua future in doubt after mauling by dominant Dubois, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: 'Disaster' to 'winning machine' - is Rodri the best in the world?, Class: ['sc-4fedabc7-3', 'zTZri']
# Tag: h2, Text: Follow BBC on:, Class: ['sc-97754ce7-1', 'friRUH']
#
# --- H3 Tags ---
#
# --- H4 Tags ---

# %% [markdown]
# ## Extract headlines from the website

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website
url = 'https://www.bbc.com/news'

# Fetch the webpage content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all 'h2' tags with class 'sc-4fedabc7-3'
    headlines = soup.find_all('h2', class_='sc-4fedabc7-3')
    
    # Print each headline
    for i, headline in enumerate(headlines, 1):
        print(f"{i}. {headline.get_text()}")
else:
    print(f"Failed to retrieve content. Status code: {response.status_code}")
# Out:
# 1. Sri Lanka election goes to historic second count
# 2. Hezbollah rocket attacks damage homes in Israel, while IDF launches more Lebanon strikes
# 3. Israel orders 45-day closure of Al Jazeera West Bank office
# 4. MrBeast is called the internet's nicest man - now he faces 54-page lawsuit
